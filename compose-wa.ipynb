# %%
import element
import musicpy as mp
# Out:
# module://ipykernel.pylab.backend_inline

# %%
cfr,_ = element.load('midi/Chopin-Op10-4.mid')
# Out:
# C:\Program Files\Python3.8\lib\site-packages\pretty_midi\pretty_midi.py:97: RuntimeWarning: Tempo, Key or Time signature change events found on non-zero tracks.  This is not a valid type 0 or type 1 MIDI file.  Tempo, Key or Time Signature may be wrong.
#   warnings.warn(

# %%
element.plotAll(cfr)

# %%
mp.play(cfr)
